# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhimanyukb/machine-learning-projects/blob/main/knn_heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
y=df.iloc[:,-1]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 519   61    1   0       148   203    0        1      161      0      0.0
# 813   53    1   0       140   203    1        0      155      1      3.1
# 885   57    1   0       165   289    1        0      124      0      1.0
# 733   44    0   2       108   141    0        1      175      0      0.6
# 744   60    0   2       102   318    0        1      160      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 561   65    0   2       155   269    0        1      148      0      0.8
# 767   68    1   0       144   193    1        1      141      0      3.4
# 874   59    1   3       160   273    0        0      125      0      0.0
# 664   66    0   3       150   226    0        1      114      0      2.6
# 397   40    1   0       110   167    0        0      114      1      2.0
#
#      slope  ca  thal
# 519      2   1     3
# 813      0   0     3
# 885      1   3     3
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.72416243,  0.63708897,  1.01839598, ..., -0.59672578,
#         -0.7172339 , -0.54557604],
#        [-1.61870687,  0.63708897, -0.90822649, ..., -0.59672578,
#         -0.7172339 ,  1.05761256],
#        [-0.27992441,  0.63708897, -0.90822649, ...,  1.01781152,
#          1.2381148 ,  1.05761256],
#        ...,
#        [-0.16835921, -1.56963949, -0.90822649, ...,  1.01781152,
#         -0.7172339 , -0.54557604],
#        [ 0.27790161,  0.63708897, -0.90822649, ..., -0.59672578,
#          0.26044045, -2.14876463],
#        [ 0.0547712 ,  0.63708897, -0.90822649, ..., -0.59672578,
#          0.26044045,  1.05761256]])

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
result=confusion_matrix(y_test,y_pred)
print('result:\t',result)
score=accuracy_score(y_test,y_pred)
print('accuracy score:\t',score)
# Out:
# result:	 [[114  35]
#  [ 11 148]]
# accuracy score:	 0.8506493506493507
